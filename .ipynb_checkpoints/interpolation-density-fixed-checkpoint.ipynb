# %%
import numpy as np
import sympy as sym
import scipy.optimize as opt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Definitions for pressure/mass/etc function evaluations

# Define Hermite basis functions

def H3 (n, t):
    
    if n == 0:
        return 1 - 3*t**2 + 2*t**3
    elif n == 1:
        return t - 2*t**2 + t**3
    elif n == 2:
        return -t**2 + t**3
    elif n == 3:
        return 3*t**2 - 2*t**3
    else:
        raise Exception('Invalid n')
        
        
# Define the interval mapping function

def tau_func (x_ab, x):
    
    return (x - x_ab[0])/(x_ab[1] - x_ab[0])


# Define the pressure interpolating function

def P_func (x_ab, P_ab, dP_ab):
    
    x_ = sym.Symbol('x')
    t_ = tau_func(x_ab, x_)
    h = x_ab[1] - x_ab[0]
    
    return P_ab[0]*H3(0, t_) + h*dP_ab[0]*H3(1, t_) + h*dP_ab[1]*H3(2, t_) + P_ab[1]*H3(3, t_)


# Define the pressure gradient interpolating function

def dP_func (x_ab, P_ab, dP_ab):
    
    x_ = sym.Symbol('x')
    P_ = P_func(x_ab, P_ab, dP_ab)

    return sym.diff(P_, x_)


# Define the mass-squared interpolating function

def m2_func (x_ab, P_ab, dP_ab):
    
    x_ = sym.Symbol('x')
    dP_ = dP_func(x_ab, P_ab, dP_ab)
        
    return -8*np.pi*sym.integrate(x_**4*dP_, x_)


# Define the density interpolating function

def rho_func (x_ab, P_ab, dP_ab, m2_a):
    
    x_ = sym.Symbol('x')
    m_ = sym.sqrt(m2_a + m2_func(x_ab, P_ab, dP_ab))
    dP_ = dP_func(x_ab, P_ab, dP_ab)
    
    return -dP_*x_**2/m_ #sym.diff(m_)/(4*np.pi*x_**2)

# %%
### Definitions for optimization

# Define i'th inequality constraint for pressure gradient

def ineq_dP (y, i):
    
    # Extract pressures and pressure gradients
    
    n = len(y)//2
    
    P = y[:n]
    dP = y[n:]
    
    # Set up constraint
    
    C = -dP[i]
    
    # Return it
    
    return C


# Define Jacobian of ineq_dP

def jac_ineq_dP (y, i):
    
    # Extract pressures and pressure gradients
    
    n = len(y)//2
    
    P = y[:n]
    dP = y[n:]
    
    # Set up constraint Jacobian
    
    dC = np.zeros(2*n)
    dC[n+i] = -1.
    
    # Return it
    
    return dC


# Define i'th inequality constraint for pressure change

def ineq_delP (y, i, left, x_AB):
    
    # Extract pressures and pressure gradients
    
    n = len(y)//2
    
    P = y[:n]
    dP = y[n:]
    
    # Set up positions of points
    
    x = np.linspace(x_AB[0], x_AB[1], n)
    
    # Calculate mean pressure slope
    
    if left:
        if i > 0:
            delP = (P[i] - P[i-1])/(x[i] - x[i-1])
        else:
            raise Exception('Mean pressure slope undefined for left=True/i=0')
    else:    
        if i < n-1:
            delP = (P[i+1] - P[i])/(x[i+1] - x[i])
        else:
            raise Exception('Mean pressure slope undefined for left=False/i=n-1')
            
    # Set up the constraint
    
    C = dP[i] - 3*delP
        
    # Return it
    
    return C

    
# Define Jacobian of ineq_delP

def jac_ineq_delP (y, i, left, x_AB):
    
    # Extract pressures and pressure gradients
    
    n = len(y)//2
    
    P = y[:n]
    dP = y[n:]
    
    # Set up positions of points
    
    x = np.linspace(x_AB[0], x_AB[1], n)
    
    # Set up constraint Jacobian
    
    dC = np.zeros(2*n)
    
    if left:
        if i > 0:
            dC[i-1] = 3/(x[i] - x[i-1])
            dC[i] = -3/(x[i] - x[i-1])
        else:
            raise Exception('Mean pressure slope undefined for left=True/i=0')
    else:    
        if i < n-1:
            dC[i] = 3/(x[i+1] - x[i])
            dC[i+1] = -3/(x[i+1] - x[i])
        else:
            raise Exception('Mean pressure slope undefined for left=False/i=n-1')
        
    dC[n+i] = 1.
    
    # Return it
    
    return dC


# Define equality constraints for pressure

def eq_P (y, i, P_i):
    
    # Extract pressures and pressure gradients
    
    n = len(y)//2
    
    P = y[:n]
    dP = y[n:]
     
    # Set up the equality constraint
    
    C = P[i] - P_i
    
    # Return it
    
    return C


# Define Jacobian of eq_P

def jac_eq_P (y, i, P_i):
    
    # Extract pressures and pressure gradients
    
    n = len(y)//2
    
    P = y[:n]
    dP = y[n:]
     
    # Set up the constraint Jacobian
    
    dC = np.zeros(2*n)
    
    dC[i] = 1.
    
    # Return it
    
    return dC


# Define equality constraints for pressure gradient

def eq_dP (y, i, dP_i):
    
    # Extract pressures and pressure gradients
    
    n = len(y)//2
    
    P = y[:n]
    dP = y[n:]
     
    # Set up the equality constraint
    
    C = dP[i] - dP_i
    
    # Return it
    
    return C


# Define Jacobian of eq_dP

def jac_eq_dP (y, i, dP_i):
    
    # Extract pressures and pressure gradients
    
    n = len(y)//2
    
    P = y[:n]
    dP = y[n:]
     
    # Set up the constraint Jacobian
    
    dC = np.zeros(2*n)
    
    dC[n+i] = 1.
    
    # Return it
    
    return dC


# Define the equality constraint for mass conservation

def eq_mass (y, x_AB, m_AB):
    
    # Extract pressures and pressure gradients
    
    n = len(y)//2
    
    P = y[:n]
    dP = y[n:]
     
    # Set up positions of points
    
    x = np.linspace(x_AB[0], x_AB[1], n)
    
    # Calculate the mass-squared sum
    
    x_ = sym.Symbol('x')

    m2 = m_AB[0]**2
    
    for i in range(1, n):
        
        x_a = x[i-1]
        P_a = P[i-1]
        dP_a = dP[i-1]
            
        x_b = x[i]
        P_b = P[i]
        dP_b = dP[i]
            
        m2_ = m2_func([x_a,x_b], [P_a,P_b], [dP_a,dP_b])
        
        m2 += m2_.evalf(subs={x_:x_b}) - m2_.evalf(subs={x_:x_a})
        
    # Set up the equality constraint
    
    C = m2 - (m_AB[1]**2 - m_AB[0]**2)
    
    # Return it
    
    return C

# Define second derivative variance function (to be minimized)

def var_d2P (y, args):
    
    # Extract pressures and pressure gradients
    
    n = len(y)//2
    
    P = y[:n]
    dP = y[n:]
    
    # Unpack extra args
    
    x_AB = args[0]
    
    # Set up positions of points
    
    x = np.linspace(x_AB[0], x_AB[1], n)
    
    # Evaluate mean second derivative
    
    mean_d2P = (dP[-1] - dP[0])/(x_AB[1] - x_AB[0])
    
    # Evaluate second derivative variance
    
    var_d2P = 0.
    
    for i in range(1,n):
        
        # Evaluate d2P at the start and end of the subinterval
        
        x_a = x[i-1]
        P_a = P[i-1]
        dP_a = dP[i-1]
            
        x_b = x[i]
        P_b = P[i]
        dP_b = dP[i]
            
        d2P_a =  6*(P_b - P_a)/(x_b - x_a)**2 - 2*(dP_b + 2*dP_a)/(x_b - x_a)
        d2P_b = -6*(P_b - P_a)/(x_b - x_a)**2 + 2*(2*dP_b + dP_a)/(x_b - x_a)
    
        # Add in the integrated contribution to the variance
        
        var_d2P += (d2P_a**2 + d2P_a*d2P_b + d2P_b**2)*(x_b - x_a)/3
            
    var_d2P /= (x_AB[1] - x_AB[0])
        
    # Return it
    
    return var_d2P


# Interval optimization routine for a fixed number (n) of interior points

def opt_inter_fix (n, x_AB, P_AB, dP_AB, m_AB):
    
    # Check that n is positive
    
    if n < 3:
        raise Exception('n is less than 3')

    # Check that the boundary pressures are monotonic
    
    if P_AB[1] > P_AB[0]:
        raise Exception('P_b is greater than P_a')

    # Check that the boundary slopes are monotonic
    
    if dP_AB[0] > 0:
        raise Exception('dP_a is greater than 0')
        
    if dP_AB[1] > 0:
        raise Exception('dP_b is greater than 0')
        
    # Set up positions of points
    
    x = np.linspace(x_AB[0], x_AB[1], n)
    
    # Set up initial guesses for pressure and pressure slopes
    
    P = np.linspace(P_AB[0], P_AB[1], n)

    dP = np.empty(n)
    dP[:] = (P_AB[0] - P_AB[1])/(x_AB[1] - x_AB[0])
    
    # Set up constraints list
    
    const_list = []
    
    # P at boundaries
    
    const_list += [{'type': 'eq',
                    'fun': eq_P,
                    'jac': jac_eq_P,
                    'args': [0, P_AB[0]]}]

    const_list += [{'type': 'eq',
                    'fun': eq_P,
                    'jac': jac_eq_P,
                    'args': [n-1, P_AB[1]]}]
    
    # dP at boundaries
    
    const_list += [{'type': 'eq',
                    'fun': eq_dP,
                    'jac': jac_eq_dP,
                    'args': [0, dP_AB[0]]}]

    const_list += [{'type': 'eq',
                    'fun': eq_dP,
                    'jac': jac_eq_dP,
                    'args': [n-1, dP_AB[1]]}]
    
    # dP at points is negative
    
    for i in range(n):
        const_list += [{'type': 'ineq',
                        'fun': ineq_dP,
                        'jac': jac_ineq_dP,
                        'args': [i]}]
        
    # Pressure in subintervals is monotonic
    
    for i in range(n):
        if i > 0:
            const_list += [{'type': 'ineq',
                            'fun': ineq_delP,
                            'jac': jac_ineq_delP,
                            'args': [i, True, x_AB]}]
        if i < n-1:
            const_list += [{'type': 'ineq',
                            'fun': ineq_delP,
                            'jac': jac_ineq_delP,
                            'args': [i, False, x_AB]}]
        
    # Mass is conserved
    
    const_list += [{'type': 'eq',
                    'fun': eq_mass,
                    'args': [x_AB, m_AB]}]
    
    # Set up the solution vector
    
    y = np.append(P, dP)
    
    # Perform the optimization
    
    res = opt.minimize(var_d2P, y, [x_AB, P_AB, dP_AB], method='SLSQP', constraints=const_list,
                      options={'eps': 1e-6, 'ftol': 1e-12, 'maxiter': 1000, 'disp': True})
    
    # Set up results data
    
    if res.success:
        
        x_ = sym.Symbol('x')
        
        P = res.x[:n]
        dP = res.x[n:]
        
        m2 = np.empty(n)
        m2[0] = m_AB[0] # shouldn't this be m_AB[0]**2 in order for this to work for every segment?
        
        rho = np.empty(n)
        rho[0] = sym.limit(rho_func([x[0],x[1]], [P[0],P[1]], [dP[0],dP[1]], m2[0]), x_, x[0])
        
        for i in range(1, n):

            x_ab = [x[i-1],x[i]]
            P_ab = [P[i-1],P[i]]
            dP_ab = [dP[i-1],dP[i]]

            m2_ = m2_func(x_ab, P_ab, dP_ab)
            m2[i] = m2[i-1] + m2_.evalf(subs={x_:x_ab[1]}) - m2_.evalf(subs={x_:x_ab[0]})
            
            rho_ = rho_func(x_ab, P_ab, dP_ab, m2[i-1])
            rho[i] = rho_.evalf(subs={x_:x_ab[1]})
            
            
    else:
        
        x = None
        P = None
        dP = None
        m2 = None
        rho = None
        
    return x, P, dP, m2, rho


# Interval optimization routine for a dynamic number of interior points

def opt_inter_dyn (x_AB, P_AB, dP_AB, m_AB):
    
    # Loop over n until we find a solution, or an upper limit is reached
    
    n_upper = 20
    
    for n in range(1+2, n_upper+1):
        
        x, P, dP, m2, rho = opt_inter_fix(n, x_AB, P_AB, dP_AB, m_AB)
        
        # Check for completion
        
        if x is not None:
            return x, P, dP, m2, rho
            
    # Return a null result
    
    return None, None, None, None, None


# Plot data

def plot_data (x, P, dP, m2, rho, n_over=25):
    
    # Check on x, P and dP
    
    if x is None:
        raise Exception('x is None')
    if P is None:
        raise Exception('P is None')
    if dP is None:
        raise Exception('dP is None')
    if m2 is None:
        raise Exception('m2 is None')
    if rho is None:
        raise Exception('rho is None')
        
    # Set up interpolation functions
    
    n = len(P)-2
    
    x_ = sym.Symbol('x')
    
    P_f = []
    dP_f = []
    m2_f = []
    rho_f = []
    
    for j in range(n+1):
        
        x_ab = [x[j],x[j+1]]
        P_ab = [P[j],P[j+1]]
        dP_ab = [dP[j],dP[j+1]]
        
        P_f += [sym.lambdify(x_, P_func(x_ab, P_ab, dP_ab), 'numpy')]
        dP_f += [sym.lambdify(x_, dP_func(x_ab, P_ab, dP_ab), 'numpy')]
        m2_f += [sym.lambdify(x_, m2_func(x_ab, P_ab, dP_ab), 'numpy')]
        rho_f += [sym.lambdify(x_, rho_func(x_ab, P_ab, dP_ab, m2[j]), 'numpy')]
    
    # Set up the interpolation x
    
    xi = np.linspace(x[0], x[-1], (n+1)*n_over+1)
    # Why n_over? Just because we already had that value defined?
    # or is the the "number of points we're interpolating over"?  Shouldn't it be "onto"?
    
    ni = len(xi)
    
    # Calculate the interpolated pressure, pressure gradient and mass
    
    Pi = np.empty(ni)
    dPi = np.empty(ni)
    m2i = np.empty(ni)
    rhoi = np.empty(ni)
    
    for i in range(ni):

        j = np.where(xi[i] >= x[:n+1])[0][-1]

        Pi[i] = P_f[j](xi[i])
        dPi[i] = dP_f[j](xi[i])
        m2i[i] = m2[j] + m2_f[j](xi[i]) - m2_f[j](x[j])
        
        if xi[i] > 0:
            rhoi[i] = rho_f[j](xi[i])
        if xi[i] == 0:
            rhoi[i] = sym.limit( rho_func([x[0],x[1]], [P[0],P[1]], [dP[0],dP[1]], m2[0]), x_, x[0] )

    # Do the plot

    fig, ax = plt.subplots(1,3, figsize=[16,4])

    ax[0].plot(xi, Pi)
    ax[0].scatter(x, P)
    ax[0].set_xlabel('x')
    ax[0].set_ylabel('P')
    
    #ax[1].plot(xi, dPi)
    #ax[1].scatter(x, dP)
    #ax[1].set_xlabel('x')
    #ax[1].set_ylabel('dP/dx')
    
    ax[1].plot(xi, np.sqrt(m2i))
    ax[1].scatter(x, np.sqrt(m2))
    ax[1].set_xlabel('x')
    ax[1].set_ylabel('m')
    
    ax[2].plot(xi, rhoi)
    ax[2].scatter(x, rho)
    ax[2].set_xlabel('x')
    ax[2].set_ylabel(r'$\rho$')
    
    fig.tight_layout()

# %% [markdown]
# ### Maximum and minimum masses for n=3

# %%
# Set up input state

x_AB = [0,1]
P_AB = [1,0]
dP_AB = [0,-0.2]
m_AB = [0,1.2] # 0.9 to 2.25 for rho_a < rho < rho_b , 
                  # which is more strict than 0.7775 to 2.6194 for m_a < m < m_b
# Note: If I keep m_B at 2.6194, it interpolates for n=3 points, but NOT for n>3 points!
# It seems as though there's not only a *minimum* number of points we can use, but also a maximum.

n = 3 # Note that n is now the *total* number of points, including endpoints

# Perform the optimization

x1, P1, dP1, m21, rho1 = opt_inter_fix(n, x_AB, P_AB, dP_AB, m_AB)

plot_data(x1, P1, dP1, m21, rho1)

###

x_AB = [0,1]
P_AB = [1,0]
dP_AB = [0,-0.2]
m_AB = [0,2.6194]

x2, P2, dP2, m22, rho2 = opt_inter_fix(n, x_AB, P_AB, dP_AB, m_AB)
#
plot_data(x2, P2, dP2, m22, rho2)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 29.021228393441284
#             Iterations: 3
#             Function evaluations: 24
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 27.855417612714493
#             Iterations: 3
#             Function evaluations: 24
#             Gradient evaluations: 3

# %%
( 2.25 - 0.9 )/( 2.6194 - 0.7775 )
# Out:
# 0.7329388131820402

# %%
ma1 = (4./3)*np.pi*rho1[0]*(x1[2]**3 - x1[0]**3)
mb1 = (4./3)*np.pi*rho1[2]*(x1[2]**3 - x1[0]**3)

print(ma1, mb1)
print(np.sqrt(m21))
# Out:
# 9.6862569423 1.27608726992
# [ 0.          0.48154481  0.7775    ]

# %%
ma2 = (4./3)*np.pi*rho2[0]*(x2[2]**3 - x2[0]**3)
mb2 = (4./3)*np.pi*rho2[2]*(x2[2]**3 - x2[0]**3)

print(ma2, mb2)
print(np.sqrt(m22))
# Out:
# 0.0 0.322759715418
# [ 0.          0.35237306  2.6194    ]

# %% [markdown]
# Note: Why does the density invert for the low mass case, and why does there seem to be a discontinuity for the high mass case?

# %% [markdown]
# Note: Also, why does n=3 only work for m_total = 0.7775 to 2.6194 ? Discuss with Rich at meeting today
#
# Can I work backwards from these two values to understand what is going on physically?
# What does the density profile have to look like in each of these scenarios? Maybe it *has* to be monotonic as well!

# %%
x_AB = [0,1]
P_AB = [1,0]
dP_AB = [0,-.2]
m_AB = [0,3.14] #2.7 doesn't work

# Perform the optimization

x, P, dP, m2, rho = opt_inter_dyn(x_AB, P_AB, dP_AB, m_AB)

plot_data(x, P, dP, m2, rho)
# Out:
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: 192.0
#             Iterations: 1
#             Function evaluations: 8
#             Gradient evaluations: 1
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 84.9039581255735
#             Iterations: 14
#             Function evaluations: 139
#             Gradient evaluations: 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-485-7e5ca87b130b> in <module>()
#       6 # Perform the optimization
#       7
# ----> 8 x, P, dP, m2, rho = opt_inter_dyn(x_AB, P_AB, dP_AB, m_AB)
#       9
#      10 plot_data(x, P, dP, m2, rho)
#
# <ipython-input-483-31b7acbe40a0> in opt_inter_dyn(x_AB, P_AB, dP_AB, m_AB)
#     445     for n in range(1+2, n_upper+1):
#     446
# --> 447         x, P, dP, m2, rho = opt_inter_fix(n, x_AB, P_AB, dP_AB, m_AB)
#     448
#     449         # Check for completion
#
# <ipython-input-483-31b7acbe40a0> in opt_inter_fix(n, x_AB, P_AB, dP_AB, m_AB)
#     394
#     395     res = opt.minimize(var_d2P, y, [x_AB, P_AB, dP_AB], method='SLSQP', constraints=const_list,
# --> 396                       options={'eps': 1e-6, 'ftol': 1e-12, 'maxiter': 1000, 'disp': True})
#     397
#     398     # Set up results data
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     456     elif meth == 'slsqp':
#     457         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 458                                constraints, callback=callback, **options)
#     459     elif meth == 'dogleg':
#     460         return _minimize_dogleg(fun, x0, args, jac, hess,
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/optimize/slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, **unknown_options)
#     372             if cons['eq']:
#     373                 c_eq = concatenate([atleast_1d(con['fun'](x, *con['args']))
# --> 374                                      for con in cons['eq']])
#     375             else:
#     376                 c_eq = zeros(0)
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/optimize/slsqp.py in <listcomp>(.0)
#     372             if cons['eq']:
#     373                 c_eq = concatenate([atleast_1d(con['fun'](x, *con['args']))
# --> 374                                      for con in cons['eq']])
#     375             else:
#     376                 c_eq = zeros(0)
#
# <ipython-input-483-31b7acbe40a0> in eq_mass(y, x_AB, m_AB)
#     233         dP_b = dP[i]
#     234
# --> 235         m2_ = m2_func([x_a,x_b], [P_a,P_b], [dP_a,dP_b])
#     236
#     237         m2 += m2_.evalf(subs={x_:x_b}) - m2_.evalf(subs={x_:x_a})
#
# <ipython-input-480-4cd46fa2fbca> in m2_func(x_ab, P_ab, dP_ab)
#      52     dP_ = dP_func(x_ab, P_ab, dP_ab)
#      53
# ---> 54     return -8*np.pi*sym.integrate(x_**4*dP_, x_)
#      55
#      56
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/integrals/integrals.py in integrate(*args, **kwargs)
#    1293     if isinstance(integral, Integral):
#    1294         return integral.doit(deep=False, meijerg=meijerg, conds=conds,
# -> 1295                              risch=risch, manual=manual)
#    1296     else:
#    1297         return integral
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     484                     function, xab[0],
#     485                     meijerg=meijerg1, risch=risch, manual=manual,
# --> 486                     conds=conds)
#     487                 if antideriv is None and meijerg1 is True:
#     488                     ret = try_meijerg(function, xab)
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/integrals/integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, conds)
#     772
#     773         # try to convert to poly(x) and then integrate if successful (fast)
# --> 774         poly = f.as_poly(x)
#     775         if poly is not None and not meijerg:
#     776             return poly.integrate().as_expr()
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/basic.py in as_poly(self, *gens, **args)
#     704
#     705         try:
# --> 706             poly = Poly(self, *gens, **args)
#     707
#     708             if not poly.is_Poly:
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/polys/polytools.py in __new__(cls, rep, *gens, **args)
#     127                 return cls._from_poly(rep, opt)
#     128             else:
# --> 129                 return cls._from_expr(rep, opt)
#     130
#     131     @classmethod
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/polys/polytools.py in _from_expr(cls, rep, opt)
#     237     def _from_expr(cls, rep, opt):
#     238         """Construct a polynomial from an expression. """
# --> 239         rep, opt = _dict_from_expr(rep, opt)
#     240         return cls._from_dict(rep, opt)
#     241
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/polys/polyutils.py in _dict_from_expr(expr, opt)
#     352         if not isinstance(expr, Expr):
#     353             raise PolynomialError('expression must be of type Expr')
# --> 354         expr = expr.expand()
#     355         # TODO: Integrate this into expand() itself
#     356         while any(_is_expandable_pow(i) or i.is_Mul and
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/expr.py in expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    3043             if use_hint:
#    3044                 hint = '_eval_expand_' + hint
# -> 3045                 expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#    3046
#    3047         while True:
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    2984
#    2985         if hasattr(expr, hint):
# -> 2986             newexpr = getattr(expr, hint)(**hints)
#    2987             if newexpr != expr:
#    2988                 return (newexpr, True)
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/mul.py in _eval_expand_mul(self, **hints)
#     880                         t = t._eval_expand_mul()
#     881                     args.append(t)
# --> 882                 return Add(*args)
#     883             else:
#     884                 return plain
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/operations.py in __new__(cls, *args, **options)
#      39             return args[0]
#      40
# ---> 41         c_part, nc_part, order_symbols = cls.flatten(args)
#      42         is_commutative = not nc_part
#      43         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/add.py in flatten(cls, seq)
#     217                 else:
#     218                     # alternatively we have to call all Mul's machinery (slow)
# --> 219                     newseq.append(Mul(c, s))
#     220
#     221             noncommutative = noncommutative or not s.is_commutative
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/operations.py in __new__(cls, *args, **options)
#      39             return args[0]
#      40
# ---> 41         c_part, nc_part, order_symbols = cls.flatten(args)
#      42         is_commutative = not nc_part
#      43         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/mul.py in flatten(cls, seq)
#     264                     return [S.NaN], [], None
#     265                 elif coeff.is_Number:  # it could be zoo
# --> 266                     coeff *= o
#     267                     if coeff is S.NaN:
#     268                         # we know for sure the result will be nan
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/numbers.py in __mul__(self, other)
#    2075             elif isinstance(other, Rational):
#    2076                 return Rational(self.p*other.p, other.q, igcd(self.p, other.q))
# -> 2077             return Rational.__mul__(self, other)
#    2078         return Rational.__mul__(self, other)
#    2079
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/decorators.py in __sympifyit_wrapper(a, b)
#      89                 if not hasattr(b, '_op_priority'):
#      90                     b = sympify(b, strict=True)
# ---> 91                 return func(a, b)
#      92             except SympifyError:
#      93                 return retval
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/numbers.py in __mul__(self, other)
#    1597                 return Rational(self.p*other.p, self.q*other.q, igcd(self.p, other.q)*igcd(self.q, other.p))
#    1598             elif isinstance(other, Float):
# -> 1599                 return other*self
#    1600             else:
#    1601                 return Number.__mul__(self, other)
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/decorators.py in __sympifyit_wrapper(a, b)
#      89                 if not hasattr(b, '_op_priority'):
#      90                     b = sympify(b, strict=True)
# ---> 91                 return func(a, b)
#      92             except SympifyError:
#      93                 return retval
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/numbers.py in __mul__(self, other)
#    1166     def __mul__(self, other):
#    1167         if isinstance(other, Number) and global_evaluate[0]:
# -> 1168             rhs, prec = other._as_mpf_op(self._prec)
#    1169             return Float._new(mlib.mpf_mul(self._mpf_, rhs, prec, rnd), prec)
#    1170         return Number.__mul__(self, other)
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/numbers.py in _as_mpf_op(self, prec)
#     593     def _as_mpf_op(self, prec):
#     594         prec = max(prec, self._prec)
# --> 595         return self._as_mpf_val(prec), prec
#     596
#     597     def __float__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sympy/core/numbers.py in _as_mpf_val(self, prec)
#    1948
#    1949     def _as_mpf_val(self, prec):
# -> 1950         return mlib.from_int(self.p, prec)
#    1951
#    1952     def _mpmath_(self, prec, rnd):
#
# ~/anaconda3/lib/python3.6/site-packages/mpmath/libmp/libmpf.py in from_int(n, prec, rnd)
#     334         if n in int_cache:
#     335             return int_cache[n]
# --> 336     return from_man_exp(n, 0, prec, rnd)
#     337
#     338 def to_man_exp(s):
#
# KeyboardInterrupt:

# %% [markdown]
# Note: It seems to be getting stuck at low n before it even tries high n.

# %% [markdown]
# ### Maximum and minimum masses for n=4

# %%
# Set up input state

x_AB = [0,1]
P_AB = [1,0]
dP_AB = [0,-0.2]
m_AB = [0,0.8087] #1.2054 to 2.6060 (2.6061, but it's *very* slow) #0.8087 to 0.8211

n = 4 # Note that n is now the *total* number of points, including endpoints

# Perform the optimization

x, P, dP, m2, rho = opt_inter_fix(n, x_AB, P_AB, dP_AB, m_AB)

plot_data(x, P, dP, m2, rho)

###

x_AB = [0,1]
P_AB = [1,0]
dP_AB = [0,-0.2]
m_AB = [0,1.2054] 

x, P, dP, m2, rho = opt_inter_fix(n, x_AB, P_AB, dP_AB, m_AB)

plot_data(x, P, dP, m2, rho)

###

x_AB = [0,1]
P_AB = [1,0]
dP_AB = [0,-0.2]
m_AB = [0,2.6060]

x, P, dP, m2, rho = opt_inter_fix(n, x_AB, P_AB, dP_AB, m_AB)

plot_data(x, P, dP, m2, rho)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 68.06355783609557
#             Iterations: 13
#             Function evaluations: 152
#             Gradient evaluations: 12
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 25.189106006461113
#             Iterations: 13
#             Function evaluations: 132
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 24.59152161311346
#             Iterations: 14
#             Function evaluations: 169
#             Gradient evaluations: 14

# %% [markdown]
# Note: the way our optimizer loops from low n to high n is slow, since it's trying to optimize for an n that might not be good.

# %%
x_AB = [0,1]
P_AB = [1,0]
dP_AB = [0,-0.2]
m_AB = [0,2.7] 

n = 6 # Note that n is now the *total* number of points, including endpoints

# Perform the optimization

x, P, dP, m2, rho = opt_inter_fix(n, x_AB, P_AB, dP_AB, m_AB)

plot_data(x, P, dP, m2, rho)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 29.803514837821574
#             Iterations: 29
#             Function evaluations: 490
#             Gradient evaluations: 29
